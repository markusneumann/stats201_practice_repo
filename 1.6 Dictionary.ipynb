# %% [markdown]
# # Notes for STATS102, Week 2
# Part of the materials are from Python for Everybody https://www.py4e.com/lessons

# %% [markdown]
# Dictionary
#
# Dictionaries are like lists except that they use keys instead of numbers to look up values

# %% [markdown]
# # 1. Dictionary

# %%
purse = dict()
purse['money'] = 12
purse['candy'] = 3
purse['tissues'] = 75
print(purse)
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}

# %%
tmp = {'money': 12, 'candy': 3, 'tissues': 75}
print(tmp)
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}

# %%
print(purse['candy'])
# Out:
# 3

# %%
purse['candy'] = purse['candy'] + 2

# %%
print(purse)
# Out:
# {'money': 12, 'candy': 5, 'tissues': 75}

# %%
jjj = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
print(jjj)
# Out:
# {'chuck': 1, 'fred': 42, 'jan': 100}

# %%
ccc = dict()
print(ccc['csev'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-21f4feaeacbb> in <module>
#       1 ccc = dict()
# ----> 2 print(ccc['csev'])
#
# KeyError: 'csev'

# %%
'csev' in ccc
# Out:
# False

# %% [markdown]
# # 2. Example- counting

# %%
counts = dict()
names = ['csev', 'cwen', 'csev', 'zqian', 'cwen']
for name in names :
    if name not in counts: 
       counts[name] = 1
    else :
        counts[name] = counts[name] + 1
print(counts)
# Out:
# {'csev': 2, 'cwen': 2, 'zqian': 1}

# %%
counts.get('cwen', 0)
# Out:
# 2

# %%
counts.get('haha', 0)
# Out:
# 0

# %% [markdown]
# ## 3. Looping

# %%
counts = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
for key in counts.keys():
    print(key, counts[key])
# Out:
# chuck 1
# fred 42
# jan 100

# %%
counts.values()
# Out:
# dict_values([1, 42, 100])

# %%
for key, value in counts.items():
    print(key, value)
# Out:
# chuck 1
# fred 42
# jan 100

# %%
dir(counts)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
a = [1,2,4]
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
jjj = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
print(list(jjj.keys()))
print(list(jjj.values()))
print(list(jjj.items()))
# Out:
# ['chuck', 'fred', 'jan']
# ['chuck', 'fred', 'jan']
# [1, 42, 100]
# [('chuck', 1), ('fred', 42), ('jan', 100)]

# %%
table = {'Name': ['A', 'B', 'C'], 'Score': [98,93,100]}

# %%
table
# Out:
# {'Name': ['A', 'B', 'C'], 'Score': [98, 93, 100]}

# %%
table['Name'].append('D')
table['Score'].append(120)

# %%
table
# Out:
# {'Name': ['A', 'B', 'C', 'D'], 'Score': [98, 93, 100, 120]}

# %% [markdown]
# # 4. Function arguments

# %%
def fun(a, **b):
    print(b)
    
fun(1, c=2, d=3)
# Out:
# {'c': 2, 'd': 3}

# %%
def fun2(a, *b):
    print(a, b)
    
fun2(1, 2, 3)
# Out:
# 1 (2, 3)
